# %%
import sys, re, os
import numpy as np
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Generate file paths
#exp_ls_csv = "fixed_rate_1024B-{}.csv"
#file_paths = [os.path.abspath(os.path.join("..\\bridge\\datasets", exp_ls_csv.format(i))) for i in [256,512,1024,4096]]

exp_ls_csv ="random_rate_exp-{}.csv"
file_paths = [os.path.abspath(os.path.join("..\\bridge\\datasets", exp_ls_csv.format(i))) for i in [2,3,4,6,7,8,9,10]]
# Read each CSV file
dataframes = [pd.read_csv(file) for file in file_paths]

# Combine all DataFrames into one
combined_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_random.csv', index=False)

# %%
current_dir = os.getcwd()

exp_ls_csv = "combined_1510B.csv"
file_path = os.path.abspath(os.path.join("..\\bridge", exp_ls_csv))

data = pd.read_csv(file_path, index_col=0)
data = data.replace(['<not counted>'], np.nan)

# %%
corr = data.corr()
correlation_list = []
for i in range(2,3):
    for j in range(i+1, len(corr.columns)):
        correlation_list.append((corr.columns[i], corr.columns[j], abs(corr.iloc[i, j])))
sorted_correlations = sorted(correlation_list, key=lambda x: x[2], reverse=True)
for correlation in sorted_correlations:
    print(f"Correlation between {correlation[0]} and {correlation[1]}: {correlation[2]:.2f}")
# Out:
# Correlation between latency and bridge-pcm_Socket 0-L2MISS: 0.68
# Correlation between latency and bridge-pcm_Socket 0-L3MPI: nan
# Correlation between latency and bridge-pcm_Socket 0-WRITE: 0.69
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L2MISS: 0.67
# Correlation between latency and bridge-pcm_Socket 0-L2MPI: 0.66
# Correlation between latency and bridge-pcm_Socket 0-L2HIT: 0.66
# Correlation between latency and bridge-pcm_Socket 0-READ: 0.66
# Correlation between latency and bridge-pcm_Socket 0-EXEC: 0.64
# Correlation between latency and bridge-pcm_Socket 0-INST: 0.64
# Correlation between latency and bridge-pcm_Socket 0-INSTnom%: 0.64
# Correlation between latency and bridge-pcm_Socket 0-INSTnom: 0.64
# Correlation between latency and bridge-pcm_Socket 1-L3OCC: 0.38
# Correlation between latency and bridge-pcm_Socket 0-IPC: 0.36
# Correlation between latency and bridge-pcm_Socket 0-PhysIPC: 0.36
# Correlation between latency and bridge-pcm_Socket 0-PhysIPC%: 0.36
# Correlation between latency and bridge-pcm_Socket 0-L3OCC: 0.31
# Correlation between latency and bridge-pcm_Socket 1-FREQ: 0.31
# Correlation between latency and bridge-pcm_Socket 1-L2HIT: 0.29
# Correlation between latency and bridge-pcm_Socket 1-PhysIPC%: 0.24
# Correlation between latency and bridge-pcm_Socket 1-IPC: 0.23
# Correlation between latency and bridge-pcm_Socket 0-TEMP: 0.22
# Correlation between latency and bridge-pcm_Socket 0-AFREQ: 0.21
# Correlation between latency and bridge-pcm_Socket 1-INST: 0.21
# Correlation between latency and bridge-pcm_Socket 0-ACYC: 0.18
# Correlation between latency and bridge-pcm_Socket 0-L3HIT: 0.12
# Correlation between latency and bridge-pcm_Socket 1-AFREQ: 0.10
# Correlation between latency and bridge-pcm_Socket 1-EXEC: 0.07
# Correlation between latency and bridge-pcm_Socket 0-FREQ: 0.07
# Correlation between latency and bridge-pcm_Socket 1-L3HIT: 0.06
# Correlation between latency and bridge-pcm_Socket 1-WRITE: 0.05
# Correlation between latency and bridge-pcm_Socket 0-LOCAL: 0.05
# Correlation between latency and bridge-pcm_Socket 0-TIME(ticks): 0.04
# Correlation between latency and bridge-pcm_Socket 1-L3MPI: 0.03
# Correlation between latency and bridge-pcm_Socket 1-L3MISS: 0.02
# Correlation between latency and bridge-pcm_Socket 1-L2MISS: 0.02
# Correlation between latency and bridge-pcm_Socket 1-READ: 0.01
# Correlation between latency and bridge-pcm_Socket 1-L2MPI: 0.00
# Correlation between latency and bridge-pcm_Socket 0-L3MISS: 0.00
# Correlation between latency and bridge-pcm_SKT0 Core C-State-C7res%: nan
# Correlation between latency and bridge-pcm_SKT0 Package C-State-C0res%: nan
# Correlation between latency and bridge-pcm_SKT0 Package C-State-C2res%: nan
# Correlation between latency and bridge-pcm_SKT0 Package C-State-C3res%: nan
# Correlation between latency and bridge-pcm_SKT0 Package C-State-C6res%: nan
# Correlation between latency and bridge-pcm_SKT0 Package C-State-C7res%: nan
# Correlation between latency and bridge-pcm_SKT1 Core C-State-C7res%: nan
# Correlation between latency and bridge-pcm_SKT1 Package C-State-C0res%: nan
# Correlation between latency and bridge-pcm_SKT1 Package C-State-C2res%: nan
# Correlation between latency and bridge-pcm_SKT1 Package C-State-C3res%: nan
# Correlation between latency and bridge-pcm_SKT1 Package C-State-C6res%: nan
# Correlation between latency and bridge-pcm_SKT1 Package C-State-C7res%: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-EXEC: 0.65
# Correlation between latency and bridge-pcm_DRAM Energy (Joules)-SKT0: 0.57
# Correlation between latency and bridge-pcm_Proc Energy (Joules)-SKT0: 0.50
# Correlation between latency and bridge-pcm_Socket 1-PhysIPC: 0.23
# Correlation between latency and bridge-pcm_Socket 1-INSTnom%: 0.21
# Correlation between latency and bridge-pcm_Socket 1-ACYC: 0.19
# Correlation between latency and bridge-pcm_SKT1 Core C-State-C0res%: 0.18
# Correlation between latency and bridge-pcm_SKT0 Core C-State-C0res%: 0.17
# Correlation between latency and bridge-pcm_Proc Energy (Joules)-SKT1: 0.15
# Correlation between latency and bridge-pcm_Socket 1-INSTnom: 0.11
# Correlation between latency and bridge-pcm_Socket 1-TEMP: 0.11
# Correlation between latency and bridge-pcm_DRAM Energy (Joules)-SKT1: 0.09
# Correlation between latency and bridge-pcm_SKT0 Core C-State-C6res%: 0.08
# Correlation between latency and bridge-pcm_SKT1 Core C-State-C6res%: 0.07
# Correlation between latency and bridge-pcm_LLCRDMISSLAT (ns)-SKT0: 0.06
# Correlation between latency and bridge-pcm_LLCRDMISSLAT (ns)-SKT1: 0.05
# Correlation between latency and bridge-pcm_Socket 1-TIME(ticks): 0.04
# Correlation between latency and bridge-pcm_UncFREQ (Ghz)-SKT1: 0.02
# Correlation between latency and bridge-pcm_Socket 1-LOCAL: 0.01
# Correlation between latency and bridge-pcm_SKT0 Core C-State-C3res%: 0.01
# Correlation between latency and bridge-pcm_SKT1 Core C-State-C3res%: 0.01
# Correlation between latency and bridge-pcm_UncFREQ (Ghz)-SKT0: 0.01
# Correlation between latency and bridge-pcm_SKT0 Core C-State-C1res%: 0.01
# Correlation between latency and bridge-pcm_SKT1 Core C-State-C1res%: 0.00
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L3HIT: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L3MPI: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L2MPI: 0.67
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-IPC: 0.67
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-C3res%: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-C6res%: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-C7res%: nan
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-PhysIPC%: 0.67
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-PhysIPC: 0.67
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-INST: 0.65
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-INSTnom%: 0.65
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-INSTnom: 0.65
# Correlation between latency and bridge-pcm_-: nan
# Correlation between latency and nf_out_nfs[i].instance_id: nan
# Correlation between latency and nf_out_nfs[i].service_id: nan
# Correlation between latency and nf_out_nfs[i].thread_info.core: nan
# Correlation between latency and nf_out_rx_pps: 0.66
# Correlation between latency and nf_out_tx_pps: 0.66
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L3OCC: 0.64
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-TEMP: 0.24
# Correlation between latency and nf_out_rx: 0.18
# Correlation between latency and nf_out_act_out: 0.18
# Correlation between latency and nf_out_tx: 0.18
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L2HIT: 0.15
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-ACYC: 0.06
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-C1res%: 0.05
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-C0res%: 0.05
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-AFREQ: 0.05
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-FREQ: 0.05
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-TIME(ticks): 0.04
# Correlation between latency and bridge-pcm_Core3 (Socket 0)-L3MISS: 0.00
# Correlation between latency and nf_out_act_tonf: nan
# Correlation between latency and nf_out_act_drop: nan
# Correlation between latency and nf_out_nfs[i].thread_info.parent: nan
# Correlation between latency and nf_out_rte_atomic16_read(&nfs[i].thread_info.children_cnt): nan
# Correlation between latency and nf_out_rx_drop_rate: 0.01
# Correlation between latency and nf_out_tx_drop_rate: nan
# Correlation between latency and nf_out_tx_drop: nan
# Correlation between latency and nf_out_act_next: nan
# Correlation between latency and nf_out_act_buffer: nan
# Correlation between latency and nf_out_act_returned: nan
# Correlation between latency and pcm-memory_new_SKT0-Ch0Write: 0.69
# Correlation between latency and pcm-memory_new_SKT0-Mem Write (MB/s): 0.69
# Correlation between latency and pcm-memory_new_System-Write: 0.69
# Correlation between latency and pcm-memory_new_SKT0-Ch1Write: 0.67
# Correlation between latency and pcm-memory_new_SKT0-Ch0Read: 0.66
# Correlation between latency and pcm-memory_new_SKT0-Mem Read (MB/s): 0.66
# Correlation between latency and pcm-memory_new_SKT0-Ch1Read: 0.66
# Correlation between latency and pcm-memory_new_System-Read: 0.64
# Correlation between latency and pcm-pcie_new_skt-0_DRd: 0.56
# Correlation between latency and pcm-pcie_new_skt-1_CRd: 0.56
# Correlation between latency and pcm-pcie_new_skt-1_DRd: 0.55
# Correlation between latency and pcm-pcie_new_skt-0_CRd: 0.54
# Correlation between latency and pcm-pcie_new_skt-1_ItoM: 0.54
# Correlation between latency and pcm-pcie_new_skt-0_RFO: 0.53
# Correlation between latency and pcm-pcie_new_skt-1_RFO: 0.51
# Correlation between latency and pcm-pcie_new_skt-1_PRd: 0.46
# Correlation between latency and pcm-pcie_new_skt-0_WiL: 0.46
# Correlation between latency and pcm-pcie_new_skt-0_PCIRdCur: 0.43
# Correlation between latency and pcm-pcie_new_skt-1_PCIRdCur: 0.39
# Correlation between latency and pcm-memory_new_SKT1-P. Write (T/s): 0.29
# Correlation between latency and pcm-pcie_new_skt-1_WiL: 0.24
# Correlation between latency and pcm-memory_new_SKT0-Memory (MB/s): 0.21
# Correlation between latency and pcm-pcie_new_skt-0_PRd: 0.19
# Correlation between latency and pcm-memory_new_SKT0-P. Write (T/s): 0.19
# Correlation between latency and pcm-memory_new_System-Memory: 0.17
# Correlation between latency and pcm-pcie_new_skt-0_ItoM: 0.15
# Correlation between latency and nf_out_rx_drop: 0.13
# Correlation between latency and pcm-memory_new_SKT1-Ch0Write: 0.03
# Correlation between latency and pcm-memory_new_SKT1-Mem Write (MB/s): 0.02
# Correlation between latency and pcm-memory_new_SKT1-Ch0Read: 0.01
# Correlation between latency and pcm-memory_new_SKT1-Memory (MB/s): 0.01
# Correlation between latency and pcm-memory_new_SKT1-Mem Read (MB/s): 0.01
# Correlation between latency and pcm-memory_new_SKT1-Ch1Read: 0.01
# Correlation between latency and pcm-memory_new_SKT1-Ch1Write: 0.01
# C:\Users\Qiong\AppData\Local\Temp\ipykernel_25424\1364367414.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
